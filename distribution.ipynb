# %%
from pylab import *
from numpy.matlib import *

# %%
b = [ 0.017027385482645, 0.014787240847717, 0.017503643466164, 0.014066109036177, 0.094913202408574, 0.012751339316406, 0.020085725569095, 0.011033476472827, 0.021808566061082, 0.0094786947148246, 0.023019598064261, 0.0087623811367952, 0.17592965990106, 0.009265540949288, 0.022065105008425, 0.010782334121649, 0.020304869111284, 0.012547568278486, 0.018781357563614, 0.013609908236492, 0.094733666296101, 0.013358328330246, 0.019258604091532, 0.011895748575074, 0.021056717586183, 0.01002528821882, 0.022717289011165, 0.008836256489245, 0.1760194279573, 0.0091162714897607, 0.022142117751576, 0.010924440851146 ]

# %%
y = [ 0.0028571428571429, 0, 0.00017186643396105, 0, 0.020493215322495, 0, 0.0001325433083943, 0, 0.0035335245813642, 0, 0.00040370469433921, 0, 0.040153490475246, 0, 0.00068886768817902, 0, 0.0038158237593515, 0, 0.00017939611843654, 0, 0.021088064398084, 0, 0.0044773488896234, 0, 0.0038166127886091, 0, 0.003698085801942, 0, 0.016534088850021, 0, 0.00056652237687792, 0 ]

# %%
bars = 1
k = arange(0,bars*2*pi, 2*pi/32)
n = c_[arange(0, 4 * bars, 1)]
s = repmat([ 0.5, 1, 0.5, 1], 1, bars).T
ref = sum(s * sinc(k*16 - (32/4*n + 32/8)*pi), 0)

plot(y)
plot((ref + 0.1)*0.2)
xlim(0, 32)
show()

# %%
repmat([ 0.5, 1, 0.5, 1], 1, bars).T
# Out:
# array([[ 0.5],
#        [ 1. ],
#        [ 0.5],
#        [ 1. ],
#        [ 0.5],
#        [ 1. ],
#        [ 0.5],
#        [ 1. ]])

# %%
# ?repmat
# Out:
# Object `repmat` not found.
