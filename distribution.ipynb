# %%
from pylab import *

# %%
k = arange(0,2*pi, 2*pi/16)
n = c_[arange(0, 4, 1)]
ref = sum(sinc(k*8 - (4*n + 2)*pi), 0)

# %%
plot(ref)
# plot(ref2)
# plot(ref3)
# plot(ref4)
show()

# %%
sin(k)/k
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':
# array([             nan,   9.74495358e-01,   9.00316316e-01,
#          7.84213304e-01,   6.36619772e-01,   4.70527982e-01,
#          3.00105439e-01,   1.39213623e-01,   3.89817183e-17,
#         -1.08277262e-01,  -1.80063263e-01,  -2.13876356e-01,
#         -2.12206591e-01,  -1.80972301e-01,  -1.28616617e-01,
#         -6.49663572e-02])

# %%
sinc(k)
# Out:
# array([ 1.        ,  0.76494998,  0.25300546, -0.14340869, -0.19765087,
#        -0.01855091,  0.12154113,  0.082164  , -0.04359863, -0.08954115,
#        -0.01842905,  0.06217845,  0.05306074, -0.02021306, -0.05789642,
#        -0.01822702])

# %%
y = [ 0.036860260716832, -0.047404764752906, 1.0128071060702, -0.067775084489504, 0.076618396556196, -0.083979446620132, 1.0444334627693, -0.092927156430046, 0.094086607004361, -0.092927156430046, 1.0444334627693, -0.083979446620132, 0.076618396556196, -0.067775084489503, 1.0128071060702, -0.047404764752906 ]

# %%
plot(y)
plot(ref)
show()

# %%
l = [ 0.020088689549827, -0.026201326254736, 0.031857338407252, -0.036740081141925, 0.99555262652446, -0.043385017476452, 0.045012560751083, -0.045588480451471, 0.045272015196938, -0.044273152958757, 0.042825842315804, -0.041163710553996, 0.9944305258215, -0.038018961725915, 0.036860260716832, -0.036125406666104, 0.035873909260703, -0.036125406666104, 0.036860260716832, -0.038018961725915, 0.9944305258215, -0.041163710553996, 0.042825842315803, -0.044273152958757, 0.045272015196938, -0.045588480451471]

# %%
plot(l)
# xlim(0, 10)
show()

# %%
y = [ 0, 0, 0.9, 0, 0, 0, 1.0304088771343, 0, 0, 0, 0.9, 0, 0, 0, 0.9, 0 ]

# %%
plot(y)
plot(ref)
show()
